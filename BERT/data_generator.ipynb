# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Load dummy police data

# %%
# Define the relative path from the 'notebooks' folder to 'data/raw/'
data_path = os.path.join("..", "data", "raw", "Police_JAN2019.csv")

# Load the dataset
df = pd.read_csv(data_path)
display(df.head()) # Show first 3 rows
print(df.shape)
# Out:
#                   District        PS Name     FIR No Date Report  \
# 0  THIRUVANANTHAPURAM CITY  Vattiyoorkavu  7000/2019  13/01/2019
# 1  THIRUVANANTHAPURAM CITY     Vanchiyoor  7001/2019  04/01/2019
# 2  THIRUVANANTHAPURAM CITY     Vanchiyoor  7002/2019  02/01/2019
# 3  THIRUVANANTHAPURAM CITY     Vanchiyoor  7003/2019  02/01/2019
# 4  THIRUVANANTHAPURAM CITY     Vanchiyoor  7004/2019  08/01/2019
#
#   Date Accident Time Report Time Accident     Sections    Accident type  \
# 0    01/12/2019    18:00:00      17:30:00  279,337,338     Minor Injury
# 1    31/12/2019    11:25:00      06:30:00          279            Fatal
# 2    24/12/2019    17:40:00      08:45:00    MO(Minor)  Grevious Injury
# 3    01/01/2019    16:13:00      14:15:00  279,337,338  Grevious Injury
# 4    17/01/2019    18:15:00      17:45:00  279,337,338  Grevious Injury
#
#    Death  ...           Spot Accident      Weather         T -Junction  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3893 entries, 0 to 3892
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   District            3893 non-null   object
#  1   PS Name             3893 non-null   object
#  2   FIR No              3893 non-null   object
#  3   Date Report         3893 non-null   object
#  4   Date Accident       3893 non-null   object
#  5   Time Report         3893 non-null   object
#  6   Time Accident       3893 non-null   object
#  7   Sections            3893 non-null   object
#  8   Accident type       3893 non-null   object
#  9   Death               3893 non-null   int64
#  10  Grievous            3893 non-null   int64
#  11  Minor               3893 non-null   int64
#  12  Pedestrian          3893 non-null   int64
#  13  Cyclist             3893 non-null   int64
#  14  Latitude            3893 non-null   float64
# ...

# %%
print(df.isnull().sum())
# Out:
# District                 0
# PS Name                  0
# FIR No                   0
# Date Report              0
# Date Accident            0
# Time Report              0
# Time Accident            0
# Sections                 0
# Accident type            0
# Death                    0
# Grievous                 0
# Minor                    0
# Pedestrian               0
# Cyclist                  0
# Latitude                 0
# Longitude                0
# Place of Occurance       0
# Type Area                0
# City/Town/ Village       0
# Lanes Road               0
# Divider                  0
# Spot Accident            0
# Weather                  0
# T -Junction           2819
# Collision                0
# Type Road                0
# Road Features            0
# Visibility               0
# Traffic Control          0
# Accussed Vehicle         0
# Victim Vehicle           0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.describe()
# Out:
#              Death     Grievous        Minor   Pedestrian      Cyclist  \
# count  3893.000000  3893.000000  3893.000000  3893.000000  3893.000000
# mean      0.098382     0.801695     0.321089     0.222964     0.029283
# std       0.309709     0.527484     0.665676     0.433818     0.173132
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     1.000000     0.000000     0.000000     0.000000
# 75%       0.000000     1.000000     1.000000     0.000000     0.000000
# max       3.000000     4.000000    14.000000     3.000000     2.000000
#
#           Latitude    Longitude
# count  3893.000000  3893.000000
# mean     10.170891    76.328801
# std       1.074726     0.468166
# min       8.306148    74.875478
# 25%       9.283515    76.071002
# 50%      10.058463    76.354855
# 75%      10.993881    76.662084
# max      12.752465    77.215566

# %%
df.describe(include=[object])
# Out:
#                District    PS Name      FIR No Date Report Date Accident  \
# count              3893       3893        3893        3893          3893
# unique               20        453        3893          31           171
# top     ERNAKULAM RURAL  Vatakara   10892/2019  01/01/2019    03/01/2019
# freq                346         36           1         230           143
#
#        Time Report Time Accident     Sections    Accident type  \
# count         3893          3893         3893             3893
# unique         753           366           51                4
# top       17:00:00      19:00:00  279,337,338  Grevious Injury
# freq           135           127         1444             2873
#
#        Place of Occurance  ...  Spot Accident      Weather  T -Junction  \
# count                3893  ...           3893         3893         1074
# unique               3418  ...             16           10            5
# ...

# %%
# Get column names
column_names = df.columns
print(column_names)
# Out:
# Index(['District', 'PS Name', 'FIR No', 'Date Report', 'Date Accident',
#        'Time Report', 'Time Accident', 'Sections', 'Accident type', 'Death',
#        'Grievous', 'Minor', 'Pedestrian', 'Cyclist', 'Latitude', 'Longitude',
#        'Place of Occurance', 'Type Area', 'City/Town/ Village', 'Lanes Road',
#        'Divider', 'Spot Accident', 'Weather', 'T -Junction', 'Collision',
#        'Type Road', 'Road Features', 'Visibility', 'Traffic Control',
#        'Accussed Vehicle', 'Victim Vehicle'],
#       dtype='object')

# %%
df1= df.drop(['District','PS Name','FIR No', 'Date Report', 'Date Accident', 'Time Report', 'Time Accident',  'Sections',  'Death',
       'Grievous', 'Minor', 'Pedestrian', 'Cyclist', 'Latitude', 'Longitude','Type Area', 'City/Town/ Village', 'T -Junction', ],axis=1)
display(df1)
# Out:
#         Accident type            Place of Occurance  Lanes Road Divider  \
# 0        Minor Injury                  MOOTHAKUNNAM      Single      no
# 1               Fatal                     KAVILNADA      Double      no
# 2     Grevious Injury                    VAZHAKULAM      Double      no
# 3     Grevious Injury                    PERUMATTAM      Double      no
# 4     Grevious Injury  NEAR FEDERAL BANK VAZHAKULAM      Double      no
# ...               ...                           ...         ...     ...
# 3888     Minor Injury                        KALADY      Single      no
# 3889  Grevious Injury                      ANGAMALY  Four lanes     yes
# 3890  Grevious Injury      ST XAVIERS COLLAGE FRONT      Single      no
# 3891  Grevious Injury                  KIZHAKKEKARA      Double      no
# 3892  Grevious Injury              KADANGALOOR ROAD      Double      no
#
#                Spot Accident      Weather               Collision  \
# ...

# %%
list_of_columns = df1.columns
list_of_columns
# Out:
# Index(['Accident type', 'Place of Occurance', 'Lanes Road', 'Divider',
#        'Spot Accident', 'Weather', 'Collision', 'Type Road', 'Road Features',
#        'Visibility', 'Traffic Control', 'Accussed Vehicle', 'Victim Vehicle'],
#       dtype='object')

# %%
# Dictionary to store unique values
unique_values = {}

# Loop through columns and get unique values
for col in list_of_columns:
    unique_values[col] = df[col].unique().tolist()

# Print unique values
for col, values in unique_values.items():
    print(f"{col}: {values}")
# Out:
# Accident type: ['Minor Injury', 'Fatal', 'Grevious Injury', 'Non Injury']
# ...
